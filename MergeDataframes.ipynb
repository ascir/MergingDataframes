# %% [markdown]
# <div style="display:block">
#     <div style="width: 20%; display: inline-block; text-align: left;">
#         <div class="crop">
#             <img src="http://networthcorp.net/NetworthCorp_LogoUsage_R1-01.jpg" style="height:75px; margin-left:0px" />
#         </div>
#     </div>
#     <div style="width: 59%; display: inline-block">
#         <h1  style="text-align: center"> Merge Dataframes</h1>
#         <div style="width: 90%; text-align: center; display: inline-block;"><i>Author:</i> <strong>NetworthCorp</strong> </div>
#     </div>
#     <div style="width: 20%; text-align: right; display: inline-block;">
#         <div style="width: 100%; text-align: left; display: inline-block;">
#             <i>Created: </i>
#             <time datetime="Enter Date" pubdate>June, 2018</time>
#         </div>
#     </div>
# </div>
#
# # Functionality
# - Function to take two dataframes and perform various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.

# %% [markdown]
# ##  Required parameters
# * Input Data frames
# * Merge types, can be merge, join, concatenate
# * Column Name
# * Merge function parameters
# * Concat function parameters

# %% [markdown]
# ## Input parameters
# * .Dataframes
# * Type of operation to be performed:
#             * concat- horizontal/ vertical
#             * merge- column name, how(inner, outer, left, right), left and right suffix, with or without index

# %% [markdown]
# ## Default parameters
# *  The location to which the outPut csv file is saved

# %% [markdown]
# ## Return
# * Returns the data frame with the merged datasets

# %% [markdown]
# # Code

# %%
import pandas as pd
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
        'data1': range(7)})
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
        'data2': range(3)})
df3 = pd.read_csv('USDAProj_Corn_2007to2008.csv')
df4 = pd.read_csv('USDAProj_Corn_2008to2009.csv')
df5 = pd.DataFrame({
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']})
df6 = pd.DataFrame({
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']})

# %%
def concat(df1, df2, param):
    if param == 'vertical': #for vertical join
        if len(df1.columns) != len(df2.columns): #check if no. of columns of the 2 df are equal
            print('Concatenation not possible, number of headers not equal') 
        else:
            if list(df1.columns.values) != list(df2.columns.values): #checks if the column headers match
                print('Concatenation not possible, headers of the 2 dataframes not equal')
            else:
                df= pd.concat([df1, df2], ignore_index= True)
                display(df) #displays concatenated df
    elif param == 'horizontal': #for horizantal join
        df= pd.concat([df1, df2], axis = 1)
        display(df)
    else:
        print('Invalid Input')

def mergewocol(df1, df2): #for simple datasets which have common column
    if len(df1.index) != len(df2.index): #checks for number of rows
        print('WARNING: Number of rows unequal') #throws warning if number of rows are unequal 
        df= pd.merge(df1, df2)
        display(df)
    else:
        df= pd.merge(df1, df2)
        display(df)


def mergeon(df1, df2, ColumnName): #merges based on one particular column
    if len(df1.index) != len(df2.index): 
        print('WARNING: Number of rows unequal')
        df= pd.merge(df1, df2, on = ColumnName)
        display(df)
    else:
        df= pd.merge(df1, df2, on = ColumnName)
        display(df)
        
def mergehow(df1, df2, ColumnName, how): #merges left/right/inner/outer
    
    if how == 'left':
        if len(df1.index) != len(df2.index):
            print('WARNING: Number of rows unequal')
            df= pd.merge(df1, df2, on = ColumnName, how = 'left')
            display(df)
        else:
            df= pd.merge(df1, df2, on = ColumnName, how = 'left')
            display(df) 
        
    elif how == 'right':
        if len(df1.index) != len(df2.index):
            print('WARNING: Number of rows unequal')
            df= pd.merge(df1, df2, on = ColumnName, how = 'right')
            display(df)
        else:
            df= pd.merge(df1, df2, on = ColumnName, how = 'right')
            display(df)        
    
    elif how == 'inner':
        if len(df1.index) != len(df2.index):
            print('WARNING: Number of rows unequal')
            df= pd.merge(df1, df2, on = ColumnName, how = 'inner')
            display(df)
        else:
            df= pd.merge(df1, df2, on = ColumnName, how = 'inner')
            display(df)        
            
    elif how == 'outer':
        if len(df1.index) != len(df2.index):
            print('WARNING: Number of rows unequal')
            df= pd.merge(df1, df2, on = ColumnName, how = 'outer')
            display(df)
        else:
            df= pd.merge(df1, df2, on = ColumnName, how = 'outer')
            display(df)
            
def mergewindex(df1, df2): #merges taking left index and right index seperately
    if len(df1.index) != len(df2.index):
        print('WARNING: Number of rows unequal')
        df= pd.merge(df_a, df_b, right_index=True, left_index=True)
        display(df)
    else:
        df= pd.merge(df_a, df_b, right_index=True, left_index=True)
        display(df)

def mergewsuffix(df1, df2, sufx1, sufx2): #user can name suffix based on which dataframe is merged
    if len(df1.index) != len(df2.index):
        print('WARNING: Number of rows unequal')
        df= df1.join(df2, lsuffix= sufx1, rsuffix= sufx2)
        display(df)
    else:
        df= df1.join(df2, lsuffix='sufx1', rsuffix='sufx2')
        display(df)

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test 1

# %%
# Test 1
# Test Data Set Import
# Call function created for this dataset
merge(df1, df2, 'key')
# Out:
# WARNING: Number of rows unequal
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %% [markdown]
# ### Pass/Fail
# Test passed

# %% [markdown]
# ## Test 2

# %%
# Test 2
# Test Data Set Import
# Call function created for this dataset
concat(df3, df4, 'vertical')
# Out:
#           Date  Area Planted  Area Harvested  Yield  Beginning Stocks  \
# 0   2007/05/11          90.5            82.9  150.3             937.0
# 1   2007/06/11          90.5            82.9  150.3             987.0
# 2   2007/07/12          92.9            85.4  150.3            1137.0
# 3   2007/08/10          92.9            85.4  152.8            1137.0
# 4   2007/09/12          92.9            85.4  155.8            1142.0
# 5   2007/10/12          93.6            86.1  154.7            1304.0
# 6   2007/11/09          93.6            86.1  153.0            1304.0
# 7   2007/12/11          93.6            86.1  153.0            1304.0
# 8   2008/01/11          93.6            86.5  151.1            1304.0
# 9   2008/02/08          93.6            86.5  151.1            1304.0
# 10  2008/03/11          93.6            86.5  151.1            1304.0
# 11  2008/04/09          93.6            86.5  151.1            1304.0
# ...

# %% [markdown]
# ### Pass/Fail
# Test Passed

# %% [markdown]
# ## Test 3

# %%
# Test 2
# Test Data Set Import
# Call function created for this dataset
mergehow(df5, df6, 'subject_id','outer')
# Out:
#   first_name_x last_name_x subject_id first_name_y last_name_y
# 0         Alex    Anderson          1          NaN         NaN
# 1          Amy    Ackerman          2          NaN         NaN
# 2        Allen         Ali          3          NaN         NaN
# 3        Alice        Aoni          4        Billy      Bonder
# 4       Ayoung     Atiches          5        Brian       Black
# 5          NaN         NaN          6         Bran     Balwner
# 6          NaN         NaN          7        Bryce       Brice
# 7          NaN         NaN          8        Betty      Btisan

# %% [markdown]
# ### Pass/Fail
# Test passed
